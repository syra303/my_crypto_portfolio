# %%
import numpy as np
import pandas as pd
from pathlib import Path
from datetime import datetime

# %%
# Feed teh data from Coinbase API to obtain our list of transaction
# In our case we will use a fake portfolio of transactions stored in a CSV. 
# The format of this CSV file is teh same as the one generated by the Coinbase API

# Read into the transaction CSV file 
filepath= Path('Coinbase/cb_buy_data.csv')
tx_df= pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
tx_df= tx_df.set_index("buy_date", drop=True)
tx_df= tx_df.drop(columns=['Unnamed: 0','payment_method_id','payment_method_resource',
                           'tx_id','tx_resource','buy_update_date',
                           'buy_committed','buy_payout_date','buy_instant', 'buy_status', 
                           'buy_total_currency', 'buy_sub_total_currency'])

# Read into the marketdata - coins prices CSV file 
filepath2= Path('coins_prices_data.csv')
px_df= pd.read_csv(filepath2, parse_dates=True, infer_datetime_format=True)
px_df= px_df.set_index("Unnamed: 0", drop=True)
px_df.index.names = ['Date']


px_df.head()
# amount = Amount in bitcoin, bitcoin cash, litecoin or ethereum
# subtotal = Fiat amount without fees
# Out:
#                 btc-usd     eth-usd  link-usd   ada-usd
# Date
# 2020-03-12  4970.788086  112.347122  2.064779  0.023961
# 2020-03-13  5563.707031  133.201813  2.421135  0.028437
# 2020-03-14  5200.366211  123.306023  2.143518  0.026009
# 2020-03-15  5392.314941  125.214302  2.109211  0.027120
# 2020-03-16  5014.479980  110.605873  1.779877  0.024121

# %%
# add fees and "price" columns
tx_df['$ price']= round(tx_df['buy_sub_total']/tx_df['buy_amount'],4)
tx_df['$ fees']= tx_df['buy_total'] - tx_df['buy_sub_total']
tx_df= tx_df.drop(columns=['buy_sub_total'])
tx_df.head()
# Out:
#                            buy_amount buy_amount_currency  buy_total resource  \
# buy_date
# 2021-08-27 01:10:24+00:00    0.365094                 DOT         10      buy
# 2021-08-20 02:28:04+00:00    0.333743                 DOT         10      buy
# 2021-08-13 03:36:17+00:00    0.420890                 DOT         10      buy
# 2021-08-06 01:17:38+00:00    0.479346                 DOT         10      buy
# 2021-07-30 03:15:52+00:00    0.578896                 DOT         10     sell
#
#                            $ price  $ fees
# buy_date
# 2021-08-27 01:10:24+00:00  24.6786    0.99
# 2021-08-20 02:28:04+00:00  26.9969    0.99
# 2021-08-13 03:36:17+00:00  21.4070    0.99
# 2021-08-06 01:17:38+00:00  18.7964    0.99
# 2021-07-30 03:15:52+00:00  15.5641    0.99

# %%
# list of coins I transacted: 
tx_coins = list(tx_df['buy_amount_currency'].unique())
print('You traded {} different coins'.format(len(tx_coins)))
# Out:
# You traded 11 different coins

# %%
tx_df['cash_flow']= np.where(tx_df['resource']== 'buy', (-1*tx_df['buy_total']), tx_df['buy_total'])
tx_df['units']= np.where(tx_df['resource']== 'buy', (tx_df['buy_amount']), (-1*tx_df['buy_amount']))
tx_df.head()
# Out:
#                            buy_amount buy_amount_currency  buy_total resource  \
# buy_date
# 2021-08-27 01:10:24+00:00    0.365094                 DOT         10      buy
# 2021-08-20 02:28:04+00:00    0.333743                 DOT         10      buy
# 2021-08-13 03:36:17+00:00    0.420890                 DOT         10      buy
# 2021-08-06 01:17:38+00:00    0.479346                 DOT         10      buy
# 2021-07-30 03:15:52+00:00    0.578896                 DOT         10     sell
#
#                            $ price  $ fees  cash_flow     units
# buy_date
# 2021-08-27 01:10:24+00:00  24.6786    0.99        -10  0.365094
# 2021-08-20 02:28:04+00:00  26.9969    0.99        -10  0.333743
# 2021-08-13 03:36:17+00:00  21.4070    0.99        -10  0.420890
# 2021-08-06 01:17:38+00:00  18.7964    0.99        -10  0.479346
# 2021-07-30 03:15:52+00:00  15.5641    0.99         10 -0.578896

# %%
# Out:
#                            buy_amount buy_amount_currency  buy_total resource  \
# buy_date
# 2021-08-27 01:10:24+00:00    0.365094                 DOT         10      buy
# 2021-08-20 02:28:04+00:00    0.333743                 DOT         10      buy
# 2021-08-13 03:36:17+00:00    0.420890                 DOT         10      buy
# 2021-08-06 01:17:38+00:00    0.479346                 DOT         10      buy
# 2021-07-30 03:15:52+00:00    0.578896                 DOT         10     sell
#
#                            $ price  $ fees  cash_flow     units  average_price
# buy_date
# 2021-08-27 01:10:24+00:00  24.6786    0.99        -10  0.365094        24.6786
# 2021-08-20 02:28:04+00:00  26.9969    0.99        -10  0.333743        26.9969
# 2021-08-13 03:36:17+00:00  21.4070    0.99        -10  0.420890        21.4070
# 2021-08-06 01:17:38+00:00  18.7964    0.99        -10  0.479346        18.7964
# 2021-07-30 03:15:52+00:00  15.5641    0.99         10 -0.578896        15.5641

# %%
# Out:
#                               cash_flow       units  average_price         PnL
# buy_amount_currency resource
# 1INCH               buy            -200   40.190605       4.830500  194.140715
#                     sell             75  -40.190605       1.702750  -68.434552
# ADA                 buy             -65   46.663820       1.309000   61.082940
#                     sell             25  -15.757129       1.492000  -23.509636
# AMP                 buy             -70  791.900665       0.065920   52.202092
#                     sell             10 -138.905130       0.057700   -8.014826
# DAI                 buy            -180  169.808607       1.014933  172.344415
# DOT                 buy             -60    2.857987      20.104283   57.457780
#                     sell             40   -2.407334      14.971700  -36.041881
# ENJ                 buy             -80   57.040365       1.337917   76.315255
# GRT                 buy            -280  249.033605       0.764892  190.483889
#                     sell             20  -23.195647       0.604825  -14.029307
# KEEP                buy             -50   90.155323       0.521550   47.020509
# MANA                buy             -25   36.781501       0.639200   23.510736
# MATIC               buy            -100   80.509603       1.160033   93.393823
#                     sell            130 -100.606280       1.211325 -121.866903
# UNI                 buy            -100   14.898267       6.511500   97.010067

# %%
tx_pnl_df= tx_df2.groupby(['buy_amount_currency']).agg({'cash_flow': 'sum',
                                                'units': 'sum',
                                                'average_price':'mean',
                                                 'PnL': 'sum'
                                                })
tx_pnl_df
# Out:
#                      cash_flow       units  average_price         PnL
# buy_amount_currency
# 1INCH                     -125    0.000000       3.266625  125.706163
# ADA                        -40   30.906691       1.400500   37.573304
# AMP                        -60  652.995534       0.061810   44.187266
# DAI                       -180  169.808607       1.014933  172.344415
# DOT                        -20    0.450653      17.537992   21.415898
# ENJ                        -80   57.040365       1.337917   76.315255
# GRT                       -260  225.837958       0.684859  176.454581
# KEEP                       -50   90.155323       0.521550   47.020509
# MANA                       -25   36.781501       0.639200   23.510736
# MATIC                       30  -20.096678       1.185679  -28.473080
# UNI                       -100   14.898267       6.511500   97.010067

# %%
## Show a table with our last position 

last_positions = tx_df.groupby(['buy_amount_currency']).agg({'units': 'sum', 'cash_flow': 'sum',
#                                                 'gain_loss': 'sum', 
                                                             }).reset_index()
last_positions

curr_prices = []
for coin in tx_coins:
    price = px_df[coin].iloc[-1]
    curr_prices.append(price)
    print(f'Done for {coin}')
len(curr_prices)


last_positions['price'] = curr_prices
last_positions['current_value'] = (last_positions.price * last_positions.units).round(2)
last_positions = last_positions.sort_values(by='current_value', ascending=False)

last_positions
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DOT'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-3330e79e097c> in <module>
#       8 curr_prices = []
#       9 for coin in tx_coins:
# ---> 10     price = px_df[coin].iloc[-1]
#      11     curr_prices.append(price)
#      12     print(f'Done for {coin}')
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DOT'

# %%
px_df['btc-usd'].iloc[-1]
# Out:
# 10774.4267578125

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gain_loss'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-d059d3dd964d> in <module>
#       2                                                                'units': 'sum',
#       3                                                                'gain_loss': 'sum',
# ----> 4                                                                'average_price':'mean'
#       5                                                               })
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1313     @Appender(_shared_docs['aggregate'])
#    1314     def aggregate(self, arg, *args, **kwargs):
# -> 1315         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    1316
#    1317     agg = aggregate
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#     184
#     185         _level = kwargs.pop('_level', None)
# --> 186         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#     187         if how is None:
#     188             return result
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     496
#     497                 try:
# --> 498                     result = _agg(arg, _agg_1dim)
#     499                 except SpecificationError:
#     500
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/base.py in _agg(arg, func)
#     447                 result = compat.OrderedDict()
#     448                 for fname, agg_how in compat.iteritems(arg):
# --> 449                     result[fname] = func(fname, agg_how)
#     450                 return result
#     451
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/base.py in _agg_1dim(name, how, subset)
#     426                 aggregate a 1-dim with how
#     427                 """
# --> 428                 colg = self._gotitem(name, ndim=1, subset=subset)
#     429                 if colg.ndim != 1:
#     430                     raise SpecificationError("nested dictionary is ambiguous "
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _gotitem(self, key, ndim, subset)
#    1341         elif ndim == 1:
#    1342             if subset is None:
# -> 1343                 subset = self.obj[key]
#    1344             return SeriesGroupBy(subset, selection=key,
#    1345                                  grouper=self.grouper)
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gain_loss'

# %%
tx_df['buy_amount_currency'].iloc[-1]
# Out:
# 'DAI'

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-20327b7f9f3b> in <module>
#       2 min_date = '2020-01-01'  # optional
#       3 tx_columns = ['date','ticker', 'cashflow', 'cml_units', 'cml_cost', 'gain_loss']
# ----> 4 tx_filter = tx_df[tx_columns]  # keeping just the most relevant ones for now
#       5
#       6 for ticker in tx_coins:
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# /opt/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['date', 'ticker', 'cashflow', 'cml_units', 'cml_cost', 'gain_loss'], dtype='object')] are in the [columns]"
